# %%
import duckdb
import pandas as pd

# %%
sql_query = '''
select * from "nyc_parking_violations_2"."main_dbt_test__audit"."violation_codes_revenue"
'''

with duckdb.connect('data/nyc_parking_violations_2.db') as con:
    display(con.sql(sql_query).df())
# Out:
#    violation_code  total_revenue_usd
# 0              41                0.0

# %%
sql_query_import_1  = '''
CREATE OR REPLACE TABLE parking_violation_codes AS
SELECT *
FROM read_csv_auto(
'data/dof_parking_violation_codes.csv',
normalize_names=True
)
'''

sql_query_import_2  = '''
CREATE OR REPLACE TABLE nyc_parking_violations_2023 AS
SELECT *
FROM read_csv_auto(
'data/parking_violations_issued_fiscal_year_2023_sample.csv',
normalize_names=True
)
'''

with duckdb.connect('data/nyc_parking_violations_project.db') as con:
    con.sql(sql_query_import_1)
    con.sql(sql_query_import_2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 19
#       1 sql_query_import_1  = '''
#       2 CREATE OR REPLACE TABLE parking_violation_codes AS
#       3 SELECT *
#    (...)
#       7 )
#       8 '''
#      10 sql_query_import_2  = '''
#      11 CREATE OR REPLACE TABLE nyc_parking_violations_2023 AS
#      12 SELECT *
#    (...)
#      16 )
#      17 '''
# ---> 19 with duckdb.connect('data/nyc_parking_violations_project.db') as con:
#      20     con.sql(sql_query_import_1)
#      21     con.sql(sql_query_import_2)
#
# NameError: name 'duckdb' is not defined

# %%
sql_query = '''
SELECT * FROM ref_model
'''

with duckdb.connect('data/nyc_parking_violations_2.db') as con:
    display(con.sql(sql_query).df())
# Out:
#    count_star()
# 0            97

# %%
sql_query_import_1  = '''
CREATE OR REPLACE TABLE parking_violation_codes AS
SELECT *
FROM read_csv_auto(
'data/dof_parking_violation_codes.csv',
normalize_names=True
)
'''

sql_query_import_2  = '''
CREATE OR REPLACE TABLE nyc_parking_violations_2023 AS
SELECT *
FROM read_csv_auto(
'data/parking_violations_issued_fiscal_year_2023_sample.csv',
normalize_names=True
)
'''

with duckdb.connect('data/prod_nyc_parking_violations_2.db') as con:
    con.sql(sql_query_import_1)
    con.sql(sql_query_import_2)

# %%
sql_query = '''
show tables
'''

with duckdb.connect('data/prod_nyc_parking_violations_2.db') as con:
    display(con.sql(sql_query).df())
# Out:
#                              name
# 0  bronze_parking_violation_codes
# 1       bronze_parking_violations
# 2                     first_model
# 3             gold_ticket_metrics
# 4            gold_vehicle_metrics
# 5     nyc_parking_violations_2023
# 6         parking_violation_codes
# 7                       ref_model
# 8        silver_violation_tickets
# 9       silver_violation_vehicles
